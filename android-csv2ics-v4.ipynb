# %%
from pathlib import Path
path = Path(r"D:\Programme\UBUNTU\Ubuntu.1604.2017.711.0_v1\rootfs\root\com.android.calendar\events-22-55-08\data.csv")

# %%
csvdata = []
import csv
with open(path,"r") as fp:
    reader = csv.DictReader(fp,skipinitialspace=True)
    #data = next(reader)
    for row in reader: # Iterate the remaining rows
        csvdata.append(row)
#csvdata

# %%
#creates dictonary that contains the events seperated by calendar 
csvcalendars = {} 
# = {calendar1Name: [Event1,...],calendar2Name: [Event1,...]}

for i in range(len(csvdata)):
    key = csvdata[i]['calendar_displayName']  # key = calendarname
    value = csvdata[i]#value = event
    
    if key not in csvcalendars:
        csvcalendars[csvdata[i]['calendar_displayName']] = [value]
    elif type(csvcalendars[key])==list:
         csvcalendars[key].append(value)
    else:
        csvcalendars[key] = [csvcalendars[key][0],value]
csvcalendars
# Out:
# {'S4-R4': [OrderedDict([('sync_data10', 'NULL'),
#                ('cal_sync6', 'NULL'),
#                ('rrule', 'FREQ=YEARLY;WKST=MO'),
#                ('sync_data6', 'NULL'),
#                ('cal_sync8', 'NULL'),
#                ('eventTimezone', 'Europe/Berlin'),
#                ('hasAttendeeData', '1'),
#                ('_sync_id', 'NULL'),
#                ('customAppPackage', 'NULL'),
#                ('originalInstanceTime', 'NULL'),
#                ('sync_data2', 'NULL'),
#                ('allowedReminders', '0 1'),
#                ('uid2445', 'NULL'),
#                ('calendar_timezone', 'NULL'),
#                ('dirty', '1'),
#                ('originalAllDay', 'NULL'),
#                ('cal_sync10', 'NULL'),
#                ('exrule', 'NULL'),
#                ('calendar_color', '-51390'),
#                ('cal_sync3', 'NULL'),
#                ('lastDate', 'NULL'),
#                ('canOrganizerRespond', '1'),
#                ('guestsCanSeeGuests', '1'),
#                ('rdate', 'NULL'),
#                ('account_type', 'LOCAL'),
#                ('eventEndTimezone', 'NULL'),
#                ('selfAttendeeStatus', '0'),
#                ('cal_sync2', 'NULL'),
#                ('mutators', 'com.android.calendar'),
#                ('exdate', 'NULL'),
#                ('hasExtendedProperties', '0'),
#                ('eventColor_index', ''),
#                ('organizer', 'Local Calendar'),
#                ('calendar_color_index', 'NULL'),
#                ('sync_data9', 'NULL'),
#                ('cal_sync5', 'NULL'),
#                ('eventColor', 'NULL'),
#                ('cal_sync4', 'NULL'),
#                ('availability', '0'),
#                ('dtstart', '1546930800000'),
#                ('ownerAccount', 'Local Calendar'),
#                ('lastSynced', '0'),
#                ('duration', 'P3600S'),
#                ('accessLevel', '0'),
#                ('maxReminders', '5'),
#                ('displayColor', '-51390'),
#                ('allDay', '0'),
#                ('eventStatus', '1'),
#                ('dtend', 'NULL'),
#                ('sync_data3', 'NULL'),
#                ('sync_data4', 'NULL'),
#                ('original_id', 'NULL'),
#                ('_id', '15'),
#                ('guestsCanModify', '0'),
#                ('customAppUri', 'NULL'),
#                ('calendar_access_level', '700'),
#                ('calendar_displayName', 'S4-R4'),
#                ('sync_data5', 'NULL'),
#                ('guestsCanInviteOthers', '1'),
#                ('sync_data8', 'NULL'),
#                ('cal_sync9', 'NULL'),
#                ('original_sync_id', 'NULL'),
#                ('cal_sync1', 'NULL'),
#                ('cal_sync7', 'NULL'),
#                ('canModifyTimeZone', '1'),
#                ('visible', '1'),
#                ('allowedAttendeeTypes', '0 1 2'),
#                ('sync_data1', 'NULL'),
#                ('allowedAvailability', '0 1'),
#                ('description', 'Description'),
#                ('title', 'Subject'),
#                ('calendar_id', '1'),
#                ('sync_data7', 'NULL'),
#                ('deleted', '0'),
#                ('eventLocation', 'Location'),
#                ('account_name', 'Local Calendar'),
#                ('hasAlarm', '1'),
#                ('isOrganizer', '1 ')]),
#   OrderedDict([('sync_data10', 'NULL'),
#                ('cal_sync6', 'NULL'),
#                ('rrule', 'NULL'),
#                ('sync_data6', 'NULL'),
#                ('cal_sync8', 'NULL'),
#                ('eventTimezone', 'UTC'),
#                ('hasAttendeeData', '0'),
#                ('_sync_id', 'NULL'),
#                ('customAppPackage', 'NULL'),
#                ('originalInstanceTime', 'NULL'),
#                ('sync_data2', 'NULL'),
#                ('allowedReminders', '0 1'),
#                ('uid2445', '62c2aa96-9cf6-47a6-97d9-1ceaf15ac7e5'),
#                ('calendar_timezone', 'NULL'),
#                ('dirty', '1'),
#                ('originalAllDay', 'NULL'),
#                ('cal_sync10', 'NULL'),
#                ('exrule', 'NULL'),
#                ('calendar_color', '-51390'),
#                ('cal_sync3', 'NULL'),
#                ('lastDate', '1559174400000'),
#                ('canOrganizerRespond', '1'),
#                ('guestsCanSeeGuests', '1'),
#                ('rdate', 'NULL'),
#                ('account_type', 'LOCAL'),
#                ('eventEndTimezone', 'UTC'),
#                ('selfAttendeeStatus', '0'),
#                ('cal_sync2', 'NULL'),
#                ('mutators', 'org.sufficientlysecure.ical'),
#                ('exdate', 'NULL'),
#                ('hasExtendedProperties', '0'),
#                ('eventColor_index', 'NULL'),
#                ('organizer', 'Local Calendar'),
#                ('calendar_color_index', 'NULL'),
#                ('sync_data9', 'NULL'),
#                ('cal_sync5', 'NULL'),
#                ('eventColor', 'NULL'),
#                ('cal_sync4', 'NULL'),
#                ('availability', '1'),
#                ('dtstart', '1559088000000'),
#                ('ownerAccount', 'Local Calendar'),
#                ('lastSynced', '0'),
#                ('duration', 'NULL'),
#                ('accessLevel', '3'),
#                ('maxReminders', '5'),
#                ('displayColor', '-51390'),
#                ('allDay', '1'),
#                ('eventStatus', 'NULL'),
#                ('dtend', '1559174400000'),
#                ('sync_data3', 'NULL'),
#                ('sync_data4', 'NULL'),
#                ('original_id', 'NULL'),
#                ('_id', '16'),
#                ('guestsCanModify', '0'),
#                ('customAppUri', 'NULL'),
#                ('calendar_access_level', '700'),
#                ('calendar_displayName', 'S4-R4'),
#                ('sync_data5', 'NULL'),
#                ('guestsCanInviteOthers', '1'),
#                ('sync_data8', 'NULL'),
#                ('cal_sync9', 'NULL'),
#                ('original_sync_id', 'NULL'),
#                ('cal_sync1', 'NULL'),
#                ('cal_sync7', 'NULL'),
#                ('canModifyTimeZone', '1'),
#                ('visible', '1'),
#                ('allowedAttendeeTypes', '0 1 2'),
#                ('sync_data1', 'NULL'),
#                ('allowedAvailability', '0 1'),
#                ('description', 'NULL'),
#                ('title', 'Mein 18.'),
#                ('calendar_id', '1'),
#                ('sync_data7', 'NULL'),
#                ('deleted', '0'),
#                ('eventLocation', '@Home'),
#                ('account_name', 'Local Calendar'),
#                ('hasAlarm', '0'),
#                ('isOrganizer', '1 ')]),
#   OrderedDict([('sync_data10', 'NULL'),
#                ('cal_sync6', 'NULL'),
#                ('rrule', 'NULL'),
#                ('sync_data6', 'NULL'),
#                ('cal_sync8', 'NULL'),
#                ('eventTimezone', 'Europe/Berlin'),
#                ('hasAttendeeData', '1'),
#                ('_sync_id', 'NULL'),
#                ('customAppPackage', 'NULL'),
#                ('originalInstanceTime', 'NULL'),
#                ('sync_data2', 'NULL'),
#                ('allowedReminders', '0 1'),
#                ('uid2445', 'NULL'),
#                ('calendar_timezone', 'NULL'),
#                ('dirty', '1'),
#                ('originalAllDay', 'NULL'),
#                ('cal_sync10', 'NULL'),
#                ('exrule', 'NULL'),
#                ('calendar_color', '-51390'),
#                ('cal_sync3', 'NULL'),
#                ('lastDate', '1547020800000'),
#                ('canOrganizerRespond', '1'),
#                ('guestsCanSeeGuests', '1'),
#                ('rdate', 'NULL'),
#                ('account_type', 'LOCAL'),
#                ('eventEndTimezone', 'NULL'),
#                ('selfAttendeeStatus', '0'),
#                ('cal_sync2', 'NULL'),
#                ('mutators', 'com.android.calendar'),
#                ('exdate', 'NULL'),
#                ('hasExtendedProperties', '0'),
#                ('eventColor_index', ''),
#                ('organizer', 'Local Calendar'),
#                ('calendar_color_index', 'NULL'),
#                ('sync_data9', 'NULL'),
#                ('cal_sync5', 'NULL'),
#                ('eventColor', 'NULL'),
#                ('cal_sync4', 'NULL'),
#                ('availability', '0'),
#                ('dtstart', '1547017200000'),
#                ('ownerAccount', 'Local Calendar'),
#                ('lastSynced', '0'),
#                ('duration', 'NULL'),
#                ('accessLevel', '0'),
#                ('maxReminders', '5'),
#                ('displayColor', '-51390'),
#                ('allDay', '0'),
#                ('eventStatus', '1'),
#                ('dtend', '1547020800000'),
#                ('sync_data3', 'NULL'),
#                ('sync_data4', 'NULL'),
#                ('original_id', 'NULL'),
#                ('_id', '17'),
#                ('guestsCanModify', '0'),
#                ('customAppUri', 'NULL'),
#                ('calendar_access_level', '700'),
#                ('calendar_displayName', 'S4-R4'),
#                ('sync_data5', 'NULL'),
#                ('guestsCanInviteOthers', '1'),
#                ('sync_data8', 'NULL'),
#                ('cal_sync9', 'NULL'),
#                ('original_sync_id', 'NULL'),
#                ('cal_sync1', 'NULL'),
#                ('cal_sync7', 'NULL'),
#                ('canModifyTimeZone', '1'),
#                ('visible', '1'),
#                ('allowedAttendeeTypes', '0 1 2'),
#                ('sync_data1', 'NULL'),
#                ('allowedAvailability', '0 1'),
#                ('description', 'KEKEKEKKEKEKKEDESCRIPTION'),
#                ('title', 'AHAHAHAHAHAHAHASUBJECT'),
#                ('calendar_id', '1'),
#                ('sync_data7', 'NULL'),
#                ('deleted', '0'),
#                ('eventLocation', 'AhahahhaLOCATUON'),
#                ('account_name', 'Local Calendar'),
#                ('hasAlarm', '1'),
#                ('isOrganizer', '1 ')])],
#  'Privat': [OrderedDict([('sync_data10', 'NULL'),
#                ('cal_sync6', "Couldn't parse iCalendar resource"),
#                ('rrule', 'NULL'),
#                ('sync_data6', 'NULL'),
#                ('cal_sync8', 'NULL'),
#                ('eventTimezone', 'Etc/UTC'),
#                ('hasAttendeeData', '1'),
#                ('_sync_id', '62c2aa96-9cf6-47a6-97d9-1ceaf15ac7e5'),
#                ('customAppPackage', 'NULL'),
#                ('originalInstanceTime', 'NULL'),
#                ('sync_data2', '1546796639000'),
#                ('allowedReminders', '0 1'),
#                ('uid2445', 'NULL'),
#                ('calendar_timezone', 'NULL'),
#                ('dirty', 'NULL'),
#                ('originalAllDay', 'NULL'),
#                ('cal_sync10', 'NULL'),
#                ('exrule', 'NULL'),
#                ('calendar_color', '-13664057'),
#                ('cal_sync3', 'NULL'),
#                ('lastDate', '1559174400000'),
#                ('canOrganizerRespond', '1'),
#                ('guestsCanSeeGuests', '1'),
#                ('rdate', 'NULL'),
#                ('account_type', 'at.bitfire.icsdroid'),
#                ('eventEndTimezone', 'Etc/UTC'),
#                ('selfAttendeeStatus', '0'),
#                ('cal_sync2', 'NULL'),
#                ('mutators', 'NULL'),
#                ('exdate', 'NULL'),
#                ('hasExtendedProperties', '0'),
#                ('eventColor_index', 'NULL'),
#                ('organizer', 'ICSdroid'),
#                ('calendar_color_index', 'NULL'),
#                ('sync_data9', 'NULL'),
#                ('cal_sync5', '1547233142259'),
#                ('eventColor', 'NULL'),
#                ('cal_sync4', 'NULL'),
#                ('availability', '1'),
#                ('dtstart', '1559088000000'),
#                ('ownerAccount', 'ICSdroid'),
#                ('lastSynced', '0'),
#                ('duration', 'NULL'),
#                ('accessLevel', '3'),
#                ('maxReminders', '5'),
#                ('displayColor', '-13664057'),
#                ('allDay', '1'),
#                ('eventStatus', 'NULL'),
#                ('dtend', '1559174400000'),
#                ('sync_data3', 'NULL'),
#                ('sync_data4', 'NULL'),
#                ('original_id', 'NULL'),
#                ('_id', '20'),
#                ('guestsCanModify', '0'),
#                ('customAppUri', 'NULL'),
#                ('calendar_access_level', '200'),
#                ('calendar_displayName', 'Privat'),
#                ('sync_data5', 'NULL'),
#                ('guestsCanInviteOthers', '1'),
#                ('sync_data8', 'NULL'),
#                ('cal_sync9', 'NULL'),
#                ('original_sync_id', 'NULL'),
#                ('cal_sync1', 'NULL'),
#                ('cal_sync7', 'NULL'),
#                ('canModifyTimeZone', '1'),
#                ('visible', '1'),
#                ('allowedAttendeeTypes', '0 2 1 3'),
#                ('sync_data1', 'NULL'),
#                ('allowedAvailability', '0 1 2'),
#                ('description', 'NULL'),
#                ('title', 'Mein 18.'),
#                ('calendar_id', '2'),
#                ('sync_data7', 'NULL'),
#                ('deleted', '0'),
#                ('eventLocation', '@Home'),
#                ('account_name', 'ICSdroid'),
#                ('hasAlarm', '0'),
#                ('isOrganizer', '1 ')])],
#  '/sdcard/Me/ComputerDocuments/sync/Calendars/Schule.ics': [OrderedDict([('sync_data10',
#                 'NULL'),
#                ('cal_sync6', 'NULL'),
#                ('rrule', 'NULL'),
#                ('sync_data6', 'NULL'),
#                ('cal_sync8', 'NULL'),
#                ('eventTimezone', 'Etc/UTC'),
#                ('hasAttendeeData', '1'),
#                ('_sync_id', '395a4d02-e657-4934-95c4-61f0257819e3'),
#                ('customAppPackage', 'NULL'),
#                ('originalInstanceTime', 'NULL'),
#                ('sync_data2', '1546882988000'),
#                ('allowedReminders', '0 1'),
#                ('uid2445', 'NULL'),
#                ('calendar_timezone', 'NULL'),
#                ('dirty', 'NULL'),
#                ('originalAllDay', 'NULL'),
#                ('cal_sync10', 'NULL'),
#                ('exrule', 'NULL'),
#                ('calendar_color', '-3723590'),
#                ('cal_sync3', 'NULL'),
#                ('lastDate', '1555113600000'),
#                ('canOrganizerRespond', '1'),
#                ('guestsCanSeeGuests', '1'),
#                ('rdate', 'NULL'),
#                ('account_type', 'at.bitfire.icsdroid'),
#                ('eventEndTimezone', 'Etc/UTC'),
#                ('selfAttendeeStatus', '0'),
#                ('cal_sync2', 'NULL'),
#                ('mutators', 'NULL'),
#                ('exdate', 'NULL'),
#                ('hasExtendedProperties', '0'),
#                ('eventColor_index', 'NULL'),
#                ('organizer', 'ICSdroid'),
#                ('calendar_color_index', 'NULL'),
#                ('sync_data9', 'NULL'),
#                ('cal_sync5', '1547233142361'),
#                ('eventColor', 'NULL'),
#                ('cal_sync4', '1546890330000'),
#                ('availability', '1'),
#                ('dtstart', '1555027200000'),
#                ('ownerAccount', 'ICSdroid'),
#                ('lastSynced', '0'),
#                ('duration', 'NULL'),
#                ('accessLevel', '0'),
#                ('maxReminders', '5'),
#                ('displayColor', '-3723590'),
#                ('allDay', '1'),
#                ('eventStatus', 'NULL'),
#                ('dtend', '1555113600000'),
#                ('sync_data3', 'NULL'),
#                ('sync_data4', 'NULL'),
#                ('original_id', 'NULL'),
#                ('_id', '21'),
#                ('guestsCanModify', '0'),
#                ('customAppUri', 'NULL'),
#                ('calendar_access_level', '200'),
#                ('calendar_displayName',
#                 '/sdcard/Me/ComputerDocuments/sync/Calendars/Schule.ics'),
#                ('sync_data5', 'NULL'),
#                ('guestsCanInviteOthers', '1'),
#                ('sync_data8', 'NULL'),
#                ('cal_sync9', 'NULL'),
#                ('original_sync_id', 'NULL'),
#                ('cal_sync1', 'NULL'),
#                ('cal_sync7', 'NULL'),
#                ('canModifyTimeZone', '1'),
#                ('visible', '1'),
#                ('allowedAttendeeTypes', '0 2 1 3'),
#                ('sync_data1', 'NULL'),
#                ('allowedAvailability', '0 1 2'),
#                ('description', 'NULL'),
#                ('title', 'Letzter Schultag'),
#                ('calendar_id', '3'),
#                ('sync_data7', 'NULL'),
#                ('deleted', '0'),
#                ('eventLocation', 'NULL'),
#                ('account_name', 'ICSdroid'),
#                ('hasAlarm', '0'),
#                ('isOrganizer', '1 ')])],
#  '/sdcard/Me/ComputerDocuments/sync/Calendars/Freizeit.ics': [OrderedDict([('sync_data10',
#                 'NULL'),
#                ('cal_sync6', 'NULL'),
#                ('rrule', 'NULL'),
#                ('sync_data6', 'NULL'),
#                ('cal_sync8', 'NULL'),
#                ('eventTimezone', 'Europe/Berlin'),
#                ('hasAttendeeData', '1'),
#                ('_sync_id', '0400b33f-2094-400f-b551-59a45d6ef77c'),
#                ('customAppPackage', 'NULL'),
#                ('originalInstanceTime', 'NULL'),
#                ('sync_data2', '1546965506000'),
#                ('allowedReminders', '0 1'),
#                ('uid2445', 'NULL'),
#                ('calendar_timezone', 'NULL'),
#                ('dirty', 'NULL'),
#                ('originalAllDay', 'NULL'),
#                ('cal_sync10', 'NULL'),
#                ('exrule', 'NULL'),
#                ('calendar_color', '-13711541'),
#                ('cal_sync3', 'NULL'),
#                ('lastDate', '1546970400000'),
#                ('canOrganizerRespond', '1'),
#                ('guestsCanSeeGuests', '1'),
#                ('rdate', 'NULL'),
#                ('account_type', 'at.bitfire.icsdroid'),
#                ('eventEndTimezone', 'Europe/Berlin'),
#                ('selfAttendeeStatus', '0'),
#                ('cal_sync2', 'NULL'),
#                ('mutators', 'NULL'),
#                ('exdate', 'NULL'),
#                ('hasExtendedProperties', '0'),
#                ('eventColor_index', 'NULL'),
#                ('organizer', 'ICSdroid'),
#                ('calendar_color_index', 'NULL'),
#                ('sync_data9', 'NULL'),
#                ('cal_sync5', '1547233142927'),
#                ('eventColor', 'NULL'),
#                ('cal_sync4', '1546981118000'),
#                ('availability', '0'),
#                ('dtstart', '1546966800000'),
#                ('ownerAccount', 'ICSdroid'),
#                ('lastSynced', '0'),
#                ('duration', 'NULL'),
#                ('accessLevel', '0'),
#                ('maxReminders', '5'),
#                ('displayColor', '-13711541'),
#                ('allDay', '0'),
#                ('eventStatus', 'NULL'),
#                ('dtend', '1546970400000'),
#                ('sync_data3', 'NULL'),
#                ('sync_data4', 'NULL'),
#                ('original_id', 'NULL'),
#                ('_id', '22'),
#                ('guestsCanModify', '0'),
#                ('customAppUri', 'NULL'),
#                ('calendar_access_level', '200'),
#                ('calendar_displayName',
#                 '/sdcard/Me/ComputerDocuments/sync/Calendars/Freizeit.ics'),
#                ('sync_data5', 'NULL'),
#                ('guestsCanInviteOthers', '1'),
#                ('sync_data8', 'NULL'),
#                ('cal_sync9', 'NULL'),
#                ('original_sync_id', 'NULL'),
#                ('cal_sync1', 'NULL'),
#                ('cal_sync7', 'NULL'),
#                ('canModifyTimeZone', '1'),
#                ('visible', '1'),
#                ('allowedAttendeeTypes', '0 2 1 3'),
#                ('sync_data1', 'NULL'),
#                ('allowedAvailability', '0 1 2'),
#                ('description', 'NULL'),
#                ('title', 'Freizeit'),
#                ('calendar_id', '4'),
#                ('sync_data7', 'NULL'),
#                ('deleted', '0'),
#                ('eventLocation', 'NULL'),
#                ('account_name', 'ICSdroid'),
#                ('hasAlarm', '0'),
#                ('isOrganizer', '1 ')])]}

# %%
import icalendar
from icalendar import Calendar, Event, vText,  vDuration
from datetime import datetime
import random

def display(cal):
    return cal.to_ical().decode('utf-8').replace('\r\n', '\n').strip()

# %%
allDay = 0 
def setAllday(b):
    global allDay
    allDay = b
def getAllday(): return bool(allDay)

# %%
import time, pytz #used for time only berlin for now | improve with localize



def timestamp_to_timeValue(epochTime):
    if(allDay):
        return timestamp_to_date(epochTime)
    elif(allDay==False):
        return timestamp_to_time(epochTime)
    else:
        raise ValueError

def timestamp_to_date(epochTime):
    return  datetime.fromtimestamp(float(epochTime)/1000.).date()#.astimezone(pytz.timezone('UTC')).replace(tzinfo=None)#.replace(tzinfo=pytz.timezone('Europe/Berlin'))#'Europe/Berlin'))
#print(timestamp_to_date('1559174400000'))

def timestamp_to_time(epochTime):
    return  datetime.fromtimestamp(float(epochTime)/1000.).astimezone(pytz.timezone('UTC')).replace(tzinfo=None)#.replace(tzinfo=pytz.timezone('Europe/Berlin'))#'Europe/Berlin'))
#timestamp_to_time('1559174400000')+

# %%
timestamp_to_timeValue('1559174400000')
# Out:
# datetime.datetime(2019, 5, 30, 0, 0)

# %%
header2componentMap = {
        "title"        :lambda v:("summary",v),
        "description"  :lambda v:("description",v),
        "eventLocation":lambda v:("location",v),
        "dtstart"      :lambda t:("dtstart",timestamp_to_timeValue(t)),
        "dtend"        :lambda t:("dtend",timestamp_to_timeValue(t)),
        #"duration"     :lambda d:("duration",vDuration.from_ical(d)), #doesnt work because it requires a pt infront of time values but there is only a p
        #allday is set when no end or duration is given doesnt work yet sets day from 2am to 2am
        #"rrule"        :lambda rule:("rrule",rule),
    }

def mapHeader2Component(headerKey,value):
    return header2componentMap[headerKey](value)
#print(*mapHeader2Component("title","1"))

# %%
icscalendars = {}
for calendarName in csvcalendars:
    icscalendars[calendarName] = Calendar()
    icscalendars[calendarName].add('prodid', '-//My calendar//')
    icscalendars[calendarName].add('version', '2.0')
    icscalendars[calendarName].add('X-WR-TIMEZONE','Europe/Berlin')

    
def add_events_to_ics(calendarName):
    for csvEvent in csvcalendars[calendarName]:
        print("EventName:",csvEvent['title'])
        event = Event()
        event['uid'] = str(random.random())+"@R4"       
        setAllday(csvEvent['allDay'])
        
        for headerKey in csvEvent:   
            
            if headerKey in header2componentMap and csvEvent[headerKey]!='NULL':
                print("   "+headerKey+" exists")
                print("       set to:"+str(mapHeader2Component(headerKey,csvEvent[headerKey])))
                event.add(*mapHeader2Component(headerKey,csvEvent[headerKey]))
                
        icscalendars[calendarName].add_component(event)
        
add_events_to_ics("S4-R4")
# Out:
# EventName: Subject
#    dtstart exists
#        set to:('dtstart', datetime.date(2019, 1, 8))
#    description exists
#        set to:('description', 'Description')
#    title exists
#        set to:('summary', 'Subject')
#    eventLocation exists
#        set to:('location', 'Location')
# EventName: Mein 18.
#    dtstart exists
#        set to:('dtstart', datetime.date(2019, 5, 29))
#    dtend exists
#        set to:('dtend', datetime.date(2019, 5, 30))
#    title exists
#        set to:('summary', 'Mein 18.')
#    eventLocation exists
#        set to:('location', '@Home')
# EventName: AHAHAHAHAHAHAHASUBJECT
#    dtstart exists
#        set to:('dtstart', datetime.date(2019, 1, 9))
#    dtend exists
#        set to:('dtend', datetime.date(2019, 1, 9))
#    description exists
#        set to:('description', 'KEKEKEKKEKEKKEDESCRIPTION')
#    title exists
#        set to:('summary', 'AHAHAHAHAHAHAHASUBJECT')
#    eventLocation exists
#        set to:('location', 'AhahahhaLOCATUON')

# %%
print(display(icscalendars["S4-R4"]))
# Out:
# BEGIN:VCALENDAR
# VERSION:2.0
# PRODID:-//My calendar//
# X-WR-TIMEZONE:Europe/Berlin
# BEGIN:VEVENT
# SUMMARY:Subject
# DTSTART;VALUE=DATE:20190108
# UID:0.6615303405666955@R4
# DESCRIPTION:Description
# LOCATION:Location
# END:VEVENT
# BEGIN:VEVENT
# SUMMARY:Mein 18.
# DTSTART;VALUE=DATE:20190529
# DTEND;VALUE=DATE:20190530
# UID:0.4185895105430397@R4
# LOCATION:@Home
# END:VEVENT
# BEGIN:VEVENT
# SUMMARY:AHAHAHAHAHAHAHASUBJECT
# DTSTART;VALUE=DATE:20190109
# DTEND;VALUE=DATE:20190109
# UID:0.8680008051083791@R4
# DESCRIPTION:KEKEKEKKEKEKKEDESCRIPTION
# LOCATION:AhahahhaLOCATUON
# END:VEVENT
# END:VCALENDAR

# %%
import tempfile, os
directory = Path(r"")
f = open(os.path.join(directory, 'MYFILEYEEEEEEEEEE.ics'), 'wb') #(filename,mode) wb indicates that the file is opened in binary mode since its a binary file
f.write(icscalendars["S4-R4"].to_ical())
f.close()
